# %% [markdown]
# **Code to run the gDPM simulation package.**
# * The code is not included due to copyright reasons, but this is a simple shell script.
# * To run the code, navigate to the correct folder using the shell and type "make" to build the simulation.
# * Type "./gdpm" to run the simulation and produce output files.

# %%
# Check compiler version
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# Package install from GitHub to use the nvcc compiler
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# Lines taken from google to link to one's google drive
# !pip install google-colab-shell
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-kx85vydr
#   Running command git clone --filter=blob:none --quiet https://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-kx85vydr
#   Resolved https://github.com/andreinechaev/nvcc4jupyter.git to commit aac710a35f52bb78ab34d2e52517237941399eff
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for NVCCPlugin: filename=NVCCPlugin-0.0.2-py3-none-any.whl size=4305 sha256=745ec13472a822322d3ef2dcdef8c7bfdd7bf6bc6f7ee38176704b5b2b2ffa0f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2r9e47tb/wheels/db/c1/1f/a2bb07bbb4a1ce3c43921252aeafaa6205f08637e292496f04
# Successfully built NVCCPlugin
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# Command shell imported from https://github.com/singhsidhukuldeep/Google-Colab-Shell
from google_colab_shell import getshell
getshell()
# Out:
# <!--https://github.com/singhsidhukuldeep/Google-Colab-Shell/-->
# <!--Using JS/CSS from official sources with backups in-case :)-->
# <div id=colab_shell></div>
# <script src="https://code.jquery.com/jquery-latest.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
# <link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
# <script>
#    $('#colab_shell').terminal(async function(command) {
#        if (command !== '') {
#            try {
#                let res = await google.colab.kernel.invokeFunction('shell', [command])
#                let out = res.data['application/json'][0]
#                this.echo(new String(out))
#            } catch(e) {
#                this.error(new String(e));
#            }
#        } else {
#            this.echo(
#              //   '>>Empty Command<<\n'+
#              //   'If you can afford use Google Colab Pro'
#                );
# ...

# %%
# !make
# Out:
# nvcc src/global.cpp src/main.cu -dc -I ./inc -std=c++11 -w -dlto
# mv *.o obj
# nvcc obj/*.o -o gdpm

# %%
# !./gdpm
# Out:
# initialize beam info successfully
# nbeams is 1
# trying to use device 0
# set device 0 success
# ...
# Initializing gDPM calculations....
# 	--ElectronAbsorptionEnergy=2.000000e+05
# 	--PhotonAbsorptionEnergy=5.000000e+04
# 	CompatibleFilePrefix = ./physics/pre4phot
# rmater: Done.
# rstep: Reading ./physics/pre4phot.step
# rscpw: Reading ./physics/pre4phot.scpw
# rbw: Reading ./physics/pre4phot.bw
# rqsurf: Reading ./physics/pre4phot.q
# rqsurf: q rejection efficiency(%):
# 7.020177e+01
# rlammo: Reading ./physics/pre4phot.lammo
# labre: Reading ./physics/pre4phot.lambre
# rrstpw: Reading ./physics/pre4phot.rstpw
# rbcon: Reading ./physics/pre4phot.brecon
# rlamph: Reading ./physics/pre4phot.lamph
# rcompt: Reading ./physics/pre4phot.compt
# rphote: Reading ./physics/pre4phot.phote
# rpairp: Reading ./physics/pre4phot.pairp
# --RandonSeed=Rand seeds are initialized.
# CT dimensions: 150 150 150
# CT resolution: 2.000000e-01 2.000000e-01 2.000000e-01
# ...
